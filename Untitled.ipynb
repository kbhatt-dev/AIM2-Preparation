# %%
import sys
print(sys.executable)
# Out:
# c:\KRISHNA\WORKSPACE\AIM2-Preparation\.venv\Scripts\python.exe

# %%
import numpy as np
import pandas as pd
import sklearn

print("Notebook environment working!")
# Out:
# Notebook environment working!
